# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Create reference to CSV file
csv_path = "Soccer2018Data.csv"

# Import the CSV into a pandas DataFrame
soccer_2018_df = pd.read_csv(csv_path, low_memory=False)
soccer_2018_df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3          L. Suárez   30     Uruguay       92         92
# 4           M. Neuer   31     Germany       92         92
#
#                   Club Preferred Position   CAM    CB   CDM  ...     RB   RCB  \
# 0       Real Madrid CF                 ST  89.0  53.0  62.0  ...   61.0  53.0
# 1         FC Barcelona                 RW  92.0  45.0  59.0  ...   57.0  45.0
# 2  Paris Saint-Germain                 LW  88.0  46.0  59.0  ...   59.0  46.0
# 3         FC Barcelona                 ST  87.0  58.0  65.0  ...   64.0  58.0
# 4     FC Bayern Munich                 GK   NaN   NaN   NaN  ...    NaN   NaN
#
#     RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 33 columns]

# %%
# Collect a list of all the unique values in "Preferred Position"
soccer_2018_df["Preferred Position"].unique()
# Out:
# array(['ST', 'RW', 'LW', 'GK', 'CDM', 'CB', 'RM', 'CM', 'LM', 'LB', 'CAM',
#        'RB', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
# Looking only at strikers (ST) to start
filtered_soccer=soccer_2018_df.loc[soccer_2018_df['Preffered Position']=='ST',:]
filtered_soccer.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3          L. Suárez   30     Uruguay       92         92
# 4           M. Neuer   31     Germany       92         92
#
#                   Club Preferred Position   CAM    CB   CDM  \
# 0       Real Madrid CF                 ST  89.0  53.0  62.0
# 1         FC Barcelona                 RW  92.0  45.0  59.0
# 2  Paris Saint-Germain                 LW  88.0  46.0  59.0
# 3         FC Barcelona                 ST  87.0  58.0  65.0
# 4     FC Bayern Munich                 GK   NaN   NaN   NaN
#
#           ...           RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST  \
# 0         ...          53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1         ...          45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2         ...          46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3         ...          58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4         ...           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    Preffered Position
# 0                  ST
# 1                  ST
# 2                  ST
# 3                  ST
# 4                  ST
#
# [5 rows x 34 columns]

# %%
# Sort the DataFrame by the values in the "ST" column to find the worst
filtered_soccer=filtered_soccer.sort('ST', ascending=False)
#test = df.sort('one', ascending=False)
# Reset the index so that the index is now based on the sorting locations
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-9f0cf06e55d4> in <module>
#       1 # Sort the DataFrame by the values in the "ST" column to find the worst
# ----> 2 filtered_soccer=filtered_soccer.sort('ST', ascending=False)
#       3 #test = df.sort('one', ascending=False)
#       4 # Reset the index so that the index is now based on the sorting locations
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
# Save all of the information collected on the worst striker
worst_striker=filtered_soccer.iloc[0]
worst_striker
# Out:
# Name                  Cristiano Ronaldo
# Age                                  32
# Nationality                    Portugal
# Overall                              94
# Potential                            94
# Club                     Real Madrid CF
# Preferred Position                   ST
# CAM                                  89
# CB                                   53
# CDM                                  62
# CF                                   91
# CM                                   82
# LAM                                  89
# LB                                   61
# LCB                                  53
# LCM                                  82
# LDM                                  62
# LF                                   91
# LM                                   89
# LS                                   92
# LW                                   91
# LWB                                  66
# RAM                                  89
# RB                                   61
# RCB                                  53
# RCM                                  82
# RDM                                  62
# RF                                   91
# RM                                   89
# RS                                   92
# RW                                   91
# RWB                                  66
# ST                                   92
# Preffered Position                   ST
# Name: 0, dtype: object
