# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as req
import time
import json
import seaborn as sns
import random
from ratelimiter import RateLimiter
from datetime import datetime
import requests

# Import API key
from config import weather_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Generate random lat/lon coordinates
counter = 0
rndlat=[]
rndlon=[]

while len(rndlat) < 750:
    lat = np.random.uniform(-90, 90)
    lon = np.random.uniform(-180,180)
    rndlat.append(lat)
    rndlon.append(lon)
    counter += 1
 

geo_df = pd.DataFrame ({"lat": rndlat, "lon":rndlon})
geo_df.head()
# Out:
#          lat         lon
# 0  66.816895  123.439510
# 1  60.427013  -64.506833
# 2 -44.456014  -58.577028
# 3 -83.792702   61.905295
# 4 -87.221483   36.626090

# %%
#feed data to citipy
city = []
country = []


for index, row in geo_df.iterrows():
    city_lat=(row["lat"])
    city_lon=(row["lon"])
    city_name = citipy.nearest_city(city_lat, city_lon).city_name
    country_code = citipy.nearest_city(city_lat, city_lon).country_code
    city.append(city_name)
    country.append(country_code)
    
city_df= pd.DataFrame ({"city": city, "country": country})
city_df.drop_duplicates(["city", "country"])
city_df.head()
# Out:
#              city country
# 0        zhigansk      ru
# 1         iqaluit      ca
# 2          viedma      ar
# 3       taolanaro      mg
# 4  port elizabeth      za

# %%
weather_data=[]

# %%
#make API calls and collect data
base_url="http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_key}&units={units}&q="
rate_limiter = RateLimiter(max_calls=50, period=60)

for index, row in city_df.iterrows():
    with rate_limiter:
        city_q=row["city"]
        response = requests.get(query_url + city_q).json()
        record_counter=1
        try:
            temp=response["main"]["temp"]
            humid=response["main"]["humidity"]
            cloud=response["clouds"]["all"]
            wind=response["wind"]["speed"]
            city_lat=response["coord"]["lat"]
            city_name=response["name"]
            city_country=response["sys"]["country"]
            weather_data.append({"City": city_name, "Country": city_country, "Latitude": city_lat,
                                "Temperature (F)": temp, "Humidity (%)": humid, "Cloudiness (%)":cloud, "Wind Speed (MPH)": wind})
            print (f"Processing record #{record_counter} -- {city_q}")
            print (f'{base_url}appid=***masked***&units={units}&q={city_q}')
            print ("----------------------------------------------------------------")
            record_counter +=1
        except:
            print (f"Weather for {city_q} not found.")
            print ("----------------------------------------------------------------")
            continue
# Out:
# Processing record #1 -- zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=zhigansk
# ----------------------------------------------------------------
# Processing record #1 -- iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=iqaluit
# ----------------------------------------------------------------
# Processing record #1 -- viedma
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=viedma
# ----------------------------------------------------------------
# Weather for taolanaro not found.
# ----------------------------------------------------------------
# Processing record #1 -- port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port elizabeth
# ----------------------------------------------------------------
# Processing record #1 -- komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=komsomolskiy
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- saint-francois
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint-francois
# ----------------------------------------------------------------
# Weather for vaitupu not found.
# ----------------------------------------------------------------
# Processing record #1 -- coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=coihaique
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- hernani
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hernani
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- castro
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=castro
# ----------------------------------------------------------------
# Processing record #1 -- griffith
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=griffith
# ----------------------------------------------------------------
# Processing record #1 -- saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint-philippe
# ----------------------------------------------------------------
# Processing record #1 -- palembang
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=palembang
# ----------------------------------------------------------------
# Processing record #1 -- lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lavrentiya
# ----------------------------------------------------------------
# Processing record #1 -- south venice
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=south venice
# ----------------------------------------------------------------
# Processing record #1 -- sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=sinnamary
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- pauini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=pauini
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mahebourg
# ----------------------------------------------------------------
# Processing record #1 -- kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kununurra
# ----------------------------------------------------------------
# Processing record #1 -- geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=geraldton
# ----------------------------------------------------------------
# Processing record #1 -- manaure
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=manaure
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hermanus
# ----------------------------------------------------------------
# Weather for barbar not found.
# ----------------------------------------------------------------
# Processing record #1 -- tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tuatapere
# ----------------------------------------------------------------
# Processing record #1 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hilo
# ----------------------------------------------------------------
# Processing record #1 -- tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tiksi
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=provideniya
# ----------------------------------------------------------------
# Processing record #1 -- severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=severo-kurilsk
# ----------------------------------------------------------------
# Weather for tumannyy not found.
# ----------------------------------------------------------------
# Processing record #1 -- mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mar del plata
# ----------------------------------------------------------------
# Processing record #1 -- cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cabo san lucas
# ----------------------------------------------------------------
# Processing record #1 -- torbay
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=torbay
# ----------------------------------------------------------------
# Processing record #1 -- turayf
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=turayf
# ----------------------------------------------------------------
# Processing record #1 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=butaritari
# ----------------------------------------------------------------
# Processing record #1 -- avarua
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=avarua
# ----------------------------------------------------------------
# Processing record #1 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=jamestown
# ----------------------------------------------------------------
# Processing record #1 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hermanus
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=labuhan
# ----------------------------------------------------------------
# Processing record #1 -- san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=san cristobal
# ----------------------------------------------------------------
# Processing record #1 -- mitu
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mitu
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- puerto palomas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto palomas
# ----------------------------------------------------------------
# Processing record #1 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=yellowknife
# ----------------------------------------------------------------
# Processing record #1 -- rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rio grande
# ----------------------------------------------------------------
# Processing record #1 -- norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=norman wells
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=plettenberg bay
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- amapa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=amapa
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Processing record #1 -- lebu
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lebu
# ----------------------------------------------------------------
# Processing record #1 -- volovo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=volovo
# ----------------------------------------------------------------
# Processing record #1 -- tamale
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tamale
# ----------------------------------------------------------------
# Processing record #1 -- whithorn
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=whithorn
# ----------------------------------------------------------------
# Processing record #1 -- chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=chernyshevskiy
# ----------------------------------------------------------------
# Processing record #1 -- tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tilichiki
# ----------------------------------------------------------------
# Processing record #1 -- leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=leningradskiy
# ----------------------------------------------------------------
# Weather for taolanaro not found.
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- salamanca
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=salamanca
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port alfred
# ----------------------------------------------------------------
# Processing record #1 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=barrow
# ----------------------------------------------------------------
# Processing record #1 -- paarl
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=paarl
# ----------------------------------------------------------------
# Processing record #1 -- mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mahebourg
# ----------------------------------------------------------------
# Processing record #1 -- kez
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kez
# ----------------------------------------------------------------
# Processing record #1 -- port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port elizabeth
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- issenye
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=issenye
# ----------------------------------------------------------------
# Weather for barentsburg not found.
# ----------------------------------------------------------------
# Processing record #1 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapaa
# ----------------------------------------------------------------
# Processing record #1 -- saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint-philippe
# ----------------------------------------------------------------
# Processing record #1 -- urucara
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=urucara
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- abu zabad
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=abu zabad
# ----------------------------------------------------------------
# Processing record #1 -- ancud
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ancud
# ----------------------------------------------------------------
# Processing record #1 -- quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=quatre cocos
# ----------------------------------------------------------------
# Processing record #1 -- imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=imbituba
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- victoria
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=victoria
# ----------------------------------------------------------------
# Processing record #1 -- lebu
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lebu
# ----------------------------------------------------------------
# Processing record #1 -- lata
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lata
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- maposeni
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=maposeni
# ----------------------------------------------------------------
# Processing record #1 -- trinidad
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=trinidad
# ----------------------------------------------------------------
# Processing record #1 -- port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port elizabeth
# ----------------------------------------------------------------
# Processing record #1 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=yellowknife
# ----------------------------------------------------------------
# Weather for saleaula not found.
# ----------------------------------------------------------------
# Processing record #1 -- oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=oranjemund
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=leningradskiy
# ----------------------------------------------------------------
# Processing record #1 -- saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saskylakh
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- eureka
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=eureka
# ----------------------------------------------------------------
# Weather for ulundurpettai not found.
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=barrow
# ----------------------------------------------------------------
# Processing record #1 -- porto walter
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=porto walter
# ----------------------------------------------------------------
# Processing record #1 -- vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vilhena
# ----------------------------------------------------------------
# Processing record #1 -- ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ilulissat
# ----------------------------------------------------------------
# Weather for vaitupu not found.
# ----------------------------------------------------------------
# Processing record #1 -- cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cidreira
# ----------------------------------------------------------------
# Processing record #1 -- college
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=college
# ----------------------------------------------------------------
# Processing record #1 -- koslan
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=koslan
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Processing record #1 -- tefe
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tefe
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- awjilah
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=awjilah
# ----------------------------------------------------------------
# Processing record #1 -- cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cidreira
# ----------------------------------------------------------------
# Processing record #1 -- gizo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=gizo
# ----------------------------------------------------------------
# Processing record #1 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hermanus
# ----------------------------------------------------------------
# Processing record #1 -- xuddur
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=xuddur
# ----------------------------------------------------------------
# Processing record #1 -- klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=klaksvik
# ----------------------------------------------------------------
# Processing record #1 -- east london
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=east london
# ----------------------------------------------------------------
# Weather for barentsburg not found.
# ----------------------------------------------------------------
# Processing record #1 -- provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=provideniya
# ----------------------------------------------------------------
# Processing record #1 -- hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hamilton
# ----------------------------------------------------------------
# Processing record #1 -- faanui
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=faanui
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=provideniya
# ----------------------------------------------------------------
# Processing record #1 -- carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=carnarvon
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Weather for taolanaro not found.
# ----------------------------------------------------------------
# Processing record #1 -- moissala
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=moissala
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Weather for belushya guba not found.
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- nedjo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=nedjo
# ----------------------------------------------------------------
# Processing record #1 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=butaritari
# ----------------------------------------------------------------
# Processing record #1 -- tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tasiilaq
# ----------------------------------------------------------------
# Processing record #1 -- hakui
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hakui
# ----------------------------------------------------------------
# Processing record #1 -- longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=longyearbyen
# ----------------------------------------------------------------
# Processing record #1 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=jamestown
# ----------------------------------------------------------------
# Processing record #1 -- faanui
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=faanui
# ----------------------------------------------------------------
# Processing record #1 -- bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bandarbeyla
# ----------------------------------------------------------------
# Processing record #1 -- lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lompoc
# ----------------------------------------------------------------
# Processing record #1 -- kalaleh
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kalaleh
# ----------------------------------------------------------------
# Processing record #1 -- boende
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=boende
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- kautokeino
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kautokeino
# ----------------------------------------------------------------
# Processing record #1 -- bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bredasdorp
# ----------------------------------------------------------------
# Processing record #1 -- srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=srednekolymsk
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- thompson
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=thompson
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bandarbeyla
# ----------------------------------------------------------------
# Processing record #1 -- tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tasiilaq
# ----------------------------------------------------------------
# Weather for taolanaro not found.
# ----------------------------------------------------------------
# Processing record #1 -- seredka
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=seredka
# ----------------------------------------------------------------
# Processing record #1 -- saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint-philippe
# ----------------------------------------------------------------
# Processing record #1 -- pisco
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=pisco
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Processing record #1 -- luena
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=luena
# ----------------------------------------------------------------
# Processing record #1 -- thompson
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=thompson
# ----------------------------------------------------------------
# Weather for barentsburg not found.
# ----------------------------------------------------------------
# Processing record #1 -- east london
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=east london
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- nurma
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=nurma
# ----------------------------------------------------------------
# Processing record #1 -- rancho palos verdes
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rancho palos verdes
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tasiilaq
# ----------------------------------------------------------------
# Processing record #1 -- puerto narino
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto narino
# ----------------------------------------------------------------
# Processing record #1 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hilo
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- san anselmo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=san anselmo
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ponta do sol
# ----------------------------------------------------------------
# Processing record #1 -- kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kavieng
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- bulgan
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bulgan
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Processing record #1 -- fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=fortuna
# ----------------------------------------------------------------
# Processing record #1 -- weihai
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=weihai
# ----------------------------------------------------------------
# Processing record #1 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hermanus
# ----------------------------------------------------------------
# Processing record #1 -- margate
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=margate
# ----------------------------------------------------------------
# Processing record #1 -- nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=nikolskoye
# ----------------------------------------------------------------
# Processing record #1 -- san vicente
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=san vicente
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mitsamiouli
# ----------------------------------------------------------------
# Processing record #1 -- atuona
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=atuona
# ----------------------------------------------------------------
# Processing record #1 -- novyy starodub
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=novyy starodub
# ----------------------------------------------------------------
# Processing record #1 -- phalombe
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=phalombe
# ----------------------------------------------------------------
# Processing record #1 -- pontes e lacerda
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=pontes e lacerda
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint-augustin
# ----------------------------------------------------------------
# Processing record #1 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hilo
# ----------------------------------------------------------------
# Processing record #1 -- nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=nikolskoye
# ----------------------------------------------------------------
# Processing record #1 -- lusambo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lusambo
# ----------------------------------------------------------------
# Processing record #1 -- bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bredasdorp
# ----------------------------------------------------------------
# Processing record #1 -- dikson
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=dikson
# ----------------------------------------------------------------
# Processing record #1 -- ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ahipara
# ----------------------------------------------------------------
# Processing record #1 -- ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ilulissat
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- torbay
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=torbay
# ----------------------------------------------------------------
# Processing record #1 -- port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port elizabeth
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- portage
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=portage
# ----------------------------------------------------------------
# Processing record #1 -- qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=qaanaaq
# ----------------------------------------------------------------
# Processing record #1 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapaa
# ----------------------------------------------------------------
# Processing record #1 -- mari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mari
# ----------------------------------------------------------------
# Processing record #1 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hilo
# ----------------------------------------------------------------
# Weather for sentyabrskiy not found.
# ----------------------------------------------------------------
# Processing record #1 -- souillac
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=souillac
# ----------------------------------------------------------------
# Processing record #1 -- ryotsu
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ryotsu
# ----------------------------------------------------------------
# Weather for haapu not found.
# ----------------------------------------------------------------
# Weather for amderma not found.
# ----------------------------------------------------------------
# Processing record #1 -- ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ilulissat
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- forestville
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=forestville
# ----------------------------------------------------------------
# Processing record #1 -- bad windsheim
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bad windsheim
# ----------------------------------------------------------------
# Processing record #1 -- faanui
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=faanui
# ----------------------------------------------------------------
# Processing record #1 -- campos altos
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=campos altos
# ----------------------------------------------------------------
# Processing record #1 -- bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bambous virieux
# ----------------------------------------------------------------
# Processing record #1 -- kenai
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kenai
# ----------------------------------------------------------------
# Processing record #1 -- ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ostrovnoy
# ----------------------------------------------------------------
# Processing record #1 -- bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bathsheba
# ----------------------------------------------------------------
# Processing record #1 -- qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=qaanaaq
# ----------------------------------------------------------------
# Weather for illoqqortoormiut not found.
# ----------------------------------------------------------------
# Weather for marcona not found.
# ----------------------------------------------------------------
# Processing record #1 -- kamaishi
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kamaishi
# ----------------------------------------------------------------
# Processing record #1 -- kahului
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kahului
# ----------------------------------------------------------------
# Processing record #1 -- marystown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=marystown
# ----------------------------------------------------------------
# Processing record #1 -- hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hithadhoo
# ----------------------------------------------------------------
# Processing record #1 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=jamestown
# ----------------------------------------------------------------
# Processing record #1 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapaa
# ----------------------------------------------------------------
# Processing record #1 -- bondo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bondo
# ----------------------------------------------------------------
# Processing record #1 -- avarua
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=avarua
# ----------------------------------------------------------------
# Processing record #1 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=yellowknife
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Processing record #1 -- port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port alfred
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapaa
# ----------------------------------------------------------------
# Processing record #1 -- kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kruisfontein
# ----------------------------------------------------------------
# Processing record #1 -- port alfred
# ...
# Processing record #1 -- vadso
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vadso
# ----------------------------------------------------------------
# Processing record #1 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=butaritari
# ----------------------------------------------------------------
# Processing record #1 -- qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=qaanaaq
# ----------------------------------------------------------------
# Processing record #1 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=yellowknife
# ----------------------------------------------------------------
# Processing record #1 -- gua musang
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=gua musang
# ----------------------------------------------------------------
# Processing record #1 -- saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saskylakh
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Processing record #1 -- touros
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=touros
# ----------------------------------------------------------------
# Processing record #1 -- skjervoy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=skjervoy
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- sumbe
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=sumbe
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- castro
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=castro
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=butaritari
# ----------------------------------------------------------------
# Processing record #1 -- deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=deputatskiy
# ----------------------------------------------------------------
# Weather for bengkulu not found.
# ----------------------------------------------------------------
# Processing record #1 -- bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bredasdorp
# ----------------------------------------------------------------
# Processing record #1 -- port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port elizabeth
# ----------------------------------------------------------------
# Processing record #1 -- muroto
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=muroto
# ----------------------------------------------------------------
# Weather for uwayl not found.
# ----------------------------------------------------------------
# Weather for taolanaro not found.
# ----------------------------------------------------------------
# Processing record #1 -- sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=sao filipe
# ----------------------------------------------------------------
# Weather for vaitupu not found.
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=butaritari
# ----------------------------------------------------------------
# Processing record #1 -- muzhi
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=muzhi
# ----------------------------------------------------------------
# Processing record #1 -- sitka
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=sitka
# ----------------------------------------------------------------
# Processing record #1 -- ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ahipara
# ----------------------------------------------------------------
# Processing record #1 -- aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=aklavik
# ----------------------------------------------------------------
# Processing record #1 -- westport
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=westport
# ----------------------------------------------------------------
# Processing record #1 -- necochea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=necochea
# ----------------------------------------------------------------
# Processing record #1 -- vangaindrano
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vangaindrano
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Processing record #1 -- comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=comodoro rivadavia
# ----------------------------------------------------------------
# Processing record #1 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapaa
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=butaritari
# ----------------------------------------------------------------
# Weather for nam tha not found.
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- dikson
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=dikson
# ----------------------------------------------------------------
# Processing record #1 -- tabas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tabas
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- mezhdurechenskiy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mezhdurechenskiy
# ----------------------------------------------------------------
# Processing record #1 -- sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=sinnamary
# ----------------------------------------------------------------
# Processing record #1 -- umea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=umea
# ----------------------------------------------------------------
# Processing record #1 -- kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kavieng
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- hereford
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hereford
# ----------------------------------------------------------------
# Processing record #1 -- kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kodiak
# ----------------------------------------------------------------
# Processing record #1 -- saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint-philippe
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Weather for grand river south east not found.
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Weather for vaitupu not found.
# ----------------------------------------------------------------
# Weather for belushya guba not found.
# ----------------------------------------------------------------
# Processing record #1 -- khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=khatanga
# ----------------------------------------------------------------
# Weather for belushya guba not found.
# ----------------------------------------------------------------
# Processing record #1 -- faanui
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=faanui
# ----------------------------------------------------------------
# Processing record #1 -- hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hithadhoo
# ----------------------------------------------------------------
# Processing record #1 -- aksu
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=aksu
# ----------------------------------------------------------------
# Processing record #1 -- kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kavieng
# ----------------------------------------------------------------
# Processing record #1 -- port blair
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port blair
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Processing record #1 -- kijang
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kijang
# ----------------------------------------------------------------
# Processing record #1 -- casablanca
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=casablanca
# ----------------------------------------------------------------
# Processing record #1 -- hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hambantota
# ----------------------------------------------------------------
# Processing record #1 -- berestechko
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=berestechko
# ----------------------------------------------------------------
# Processing record #1 -- grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=grand gaube
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=constitucion
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- goundam
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=goundam
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Weather for kismayo not found.
# ----------------------------------------------------------------
# Processing record #1 -- narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=narsaq
# ----------------------------------------------------------------
# Processing record #1 -- upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=upernavik
# ----------------------------------------------------------------
# Processing record #1 -- nortelandia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=nortelandia
# ----------------------------------------------------------------
# Processing record #1 -- touros
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=touros
# ----------------------------------------------------------------
# Weather for nizhneyansk not found.
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Processing record #1 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=yellowknife
# ----------------------------------------------------------------

# %%
#get count of cities with collected data
print (len(weather_data))
# Out:
# 676

# %%
weather_df=pd.DataFrame(weather_data)
weather_df=weather_df[["City", "Country","Latitude","Temperature (F)", "Humidity (%)", "Cloudiness (%)", "Wind Speed (MPH)"]]
weather_df.head()
# Out:
#              City Country  Latitude  Temperature (F)  Humidity (%)  \
# 0        Zhigansk      RU     66.77            55.08            96
# 1         Iqaluit      CA     63.75            46.18           100
# 2          Viedma      AR    -40.81            49.13            61
# 3  Port Elizabeth      US     39.31            74.73            88
# 4    Komsomolskiy      RU     67.55            47.60            66
#
#    Cloudiness (%)  Wind Speed (MPH)
# 0             100             11.65
# 1              90              2.24
# 2             100             13.53
# 3              75              5.82
# 4              83             15.41

# %% [markdown]
# ## Generate Cities List

# %%
weather_df.to_csv("weather_data.csv")

# %%
date = datetime.now()
date = date.strftime("%m-%d-%Y")

plt.scatter(weather_df["Latitude"], weather_df["Temperature (F)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Temperature ($^\circ$F)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("temp.png")
plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Humidity (%)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Humidity (%)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("humidity.png")
plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness (%)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Cloudiness (%)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("clouds.png")
plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed (MPH)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Wind Speed (MPH)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("wind.png")
plt.show()

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
